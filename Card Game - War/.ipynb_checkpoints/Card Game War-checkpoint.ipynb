# %%
import random
suits = ('Hearts','Diamonds','Spades','Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {"Two": 2, "Three": 3, "Four": 4, "Five": 5, "Six": 6, "Seven": 7, "Eight": 8, "Nine": 9, "Ten": 10, "Jack": 11, "Queen": 12, "King": 13, "Ace": 14}

# %%
class Card:
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]

    def __str__(self):
        return self.rank + " of " + self.suit

# %%
class Deck:
    def __init__(self):
        self.all_cards = []

        for suit in suits:
            for rank in ranks:
                created_card = Card(suit,rank)
                self.all_cards.append(created_card)

    def shuffle(self):
        random.shuffle(self.all_cards)

    def deal_one(self):
        return self.all_cards.pop()

# %%
new_deck = Deck()

# %%
mycard = new_deck.deal_one()

# %%
class Player:

    def __init__(self, name):
        self.name = name
        self.all_cards = []

    def remove_one(self):
        return self.all_cards.pop(0)
        
    def add_cards(self,new_cards):
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)

    def __str__(self):
        return f'{self.name} has {len(self.all_cards)} cards.'

# %%
new_player = Player("Dip")

# %%
print(new_player)
# Out:
# Dip has 0 cards.

# %%
new_player.add_cards(mycard)

# %%
print(new_player)
# Out:
# Dip has 1 cards.

# %%
new_player.add_cards([mycard,mycard,mycard])

# %%
print(new_player)
# Out:
# Dip has 3 cards.

# %%
new_player.remove_one()

# %%
#GAME SETUP
player_one = Player("One")
player_two = Player("Two")

new_deck = Deck()
new_deck.shuffle()

for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
len(player_one.all_cards)
# Out:
# 26

# %%
game_on = True

# %%
round_num = 0

while game_on:
    
    round_num += 1
    print(f'Round {round_num}')

    if len(player_one.all_cards) == 0:
        print("Player one is out for card. Player Two wins!")
        game_on = False
        break

    if len(player_two.all_cards) == 0:
        print("Player one is out for card. Player One wins!")
        game_on = False
        break
        
    #Start a new round
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())

    #while at war
    at_war = False
    while at_war:
        if player_one_cards[-1].value > player_two_cards[-1].value:
            player_one.add_cards(palyer_one_card[-1])
            player_two.add_cards(palyer_two_card[-1])

            at_war = False

        elif player_one_cards[-1].value < player_two_cards[-1].value:
            player_two.add_cards(palyer_one_card[-1])
            player_two.add_cards(palyer_two_card[-1])

            at_war = False

        else:
            print(
# Out:
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# Round 13
# Round 14
# Round 15
# Round 16
# Round 17
# Round 18
# Round 19
# Round 20
# Round 21
# Round 22
# Round 23
# Round 24
# Player one is out for card. Player Two wins!

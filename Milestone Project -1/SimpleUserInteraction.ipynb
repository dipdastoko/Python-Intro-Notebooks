# %%
game_list = [0,1,2]

# %%
def display_game(game_list):
    print("Here is the current list: ")
    print(game_list)

# %%
display_game(game_list)
# Out:
# Here is the current list:
# [0, 1, 2]

# %%
def position_choice():
    choice = 'wrong'
    while choice not in ['0','1','2']:
        choice = input("Please choose position(0,1 or 2): ")
        if choice not in ['0','1','2']:
            print("Invalid Choice")
    return int(choice)

# %%
position_choice()
# Out:
# Please choose position(0,1 or 2):  3
# Invalid Choice
# Please choose position(0,1 or 2):  1
# 1

# %%
def replacement_choice(game_list,position):
    user_placement = input("Type a string to place at position: ")
    game_list[position] = user_placement
    return game_list

# %%
replacement_choice(game_list,1)
# Out:
# Type a string to place at position:  test
# [0, 'test', 2]

# %%
def gameon_choice():
    choice = 'wrong'
    while choice not in ['Y','N']:
        choice = input("Do you want to continue(Y or N): ")
        if choice not in ['Y','N']:
            print("Invalid Choice")
    if choice == 'Y':
        return True
    else:
        return False

# %%
gameon_choice()
# Out:
# Do you want to continue(Y or N):  N
# False

# %%
game_on = True
game_list = [0,1,2]
while game_on:
    display_game(game_list)
    position = position_choice()
    game_list = replacement_choice(game_list,position)
    display_game(game_list)
    game_on = gameon_choice()
# Out:
# Here is the current list:
# [0, 1, 2]
# Please choose position(0,1 or 2):  0
# Type a string to place at position:  x
# Here is the current list:
# ['x', 1, 2]
# Do you want to continue(Y or N):  1
# Invalid Choice
# Do you want to continue(Y or N):  o
# Invalid Choice
# Do you want to continue(Y or N):  2
# Invalid Choice
# Do you want to continue(Y or N):  x
# Invalid Choice
# Do you want to continue(Y or N):  Y
# Here is the current list:
# ['x', 1, 2]
# Please choose position(0,1 or 2):  1
# Type a string to place at position:  O
# Here is the current list:
# ['x', 'O', 2]
# Do you want to continue(Y or N):  Y
# Here is the current list:
# ['x', 'O', 2]
# Please choose position(0,1 or 2):  2
# Type a string to place at position:  O
# Here is the current list:
# ['x', 'O', 'O']
# Do you want to continue(Y or N):  N

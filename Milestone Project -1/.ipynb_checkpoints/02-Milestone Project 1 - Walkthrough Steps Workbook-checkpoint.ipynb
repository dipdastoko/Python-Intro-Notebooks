# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Milestone Project 1: Walkthrough Steps Workbook
#
# Below is a set of steps for you to follow to try to create the Tic Tac Toe Milestone Project game!

# %% [markdown]
# #### Some suggested tools before you get started:
# To take input from a user:
#
#     player1 = input("Please pick a marker 'X' or 'O'")
#
# Note that input() takes in a string. If you need an integer value, use
#
#     position = int(input('Please enter a number'))
#
# <br>To clear the screen between moves:
#
#     from IPython.display import clear_output
#     clear_output()
#
# Note that clear_output() will only work in jupyter. To clear the screen in other IDEs, consider:
#
#     print('\n'*100)
#
# This scrolls the previous board up out of view. Now on to the program!

# %% [markdown]
# **Step 1: Write a function that can print out a board. Set up your board as a list, where each index 1-9 corresponds with a number on a number pad, so you get a 3 by 3 board representation.**

# %%
from IPython.display import clear_output

def display_board(board):
    print(board[7] +"|" + board[8] +"|"+ board[9])
    print("--"+"--"+"--")
    print(board[4] +"|" + board[5] +"|"+ board[6])
    print("--"+"--"+"--")
    print(board[1] +"|" + board[2] +"|"+ board[3])

# %% [markdown]
# **TEST Step 1:** run your function on a test version of the board list, and make adjustments as necessary

# %%
test_board = ['#','X',' ',' ',' ',' ',' ',' ',' ',' ']
display_board(test_board)
# Out:
#  | |
# ------
#  | |
# ------
# X| |

# %% [markdown]
# **Step 2: Write a function that can take in a player input and assign their marker as 'X' or 'O'. Think about using *while* loops to continually ask until you get a correct answer.**

# %%
def player_input():
    marker = ''
    while marker != "X" and marker != "O":
        marker = input("Player1, please choose your mark: X or O").upper()
    if marker == "X":
        p1 = "X"
        p2 = "O"
    else:
        p1 = "O"
        p2 = "X"
    return (p1,p2)

# %% [markdown]
# **TEST Step 2:** run the function to make sure it returns the desired output

# %%
player_input()[0]
# Out:
# Player1, please choose your mark: X or O x
# 'X'

# %% [markdown]
# **Step 3: Write a function that takes in the board list object, a marker ('X' or 'O'), and a desired position (number 1-9) and assigns it to the board.**

# %%
def place_marker(board, marker, position):
    while position not in range(1,10):
        position = int(input("please choose the position among 1-9"))
    board[position] = marker

# %% [markdown]
# **TEST Step 3:** run the place marker function using test parameters and display the modified board

# %%
place_marker(test_board,'$',8)
display_board(test_board)
# Out:
#  |$|
# ------
#  | |
# ------
#  | |

# %% [markdown]
# **Step 4: Write a function that takes in a board and a mark (X or O) and then checks to see if that mark has won. **

# %%
def win_check(board, mark):
    if board[1] == mark and board[2] == mark and board[3] == mark:
        print(f"{mark} won")
    elif board[4] == mark and board[5] == mark and board[6] == mark:
        print(f"{mark} won")
    elif board[7] == mark and board[8] == mark and board[9] == mark:
        print(f"{mark} won")
    elif board[1] == mark and board[4] == mark and board[7] == mark:
        print(f"{mark} won")
    elif board[2] == mark and board[5] == mark and board[8] == mark:
        print(f"{mark} won")
    elif board[3] == mark and board[6] == mark and board[9] == mark:
        print(f"{mark} won")
    elif board[1] == mark and board[5] == mark and board[9] == mark:
        print(f"{mark} won")
    elif board[3] == mark and board[5] == mark and board[7] == mark:
        print(f"{mark} won")
    else:
        print(f"{mark} lost")
    pass

# %% [markdown]
# **TEST Step 4:** run the win_check function against our test_board - it should return True

# %%
win_check(test_board,'X')
# Out:
# X lost

# %% [markdown]
# **Step 5: Write a function that uses the random module to randomly decide which player goes first. You may want to lookup random.randint() Return a string of which player went first.**

# %%
import random

def choose_first():
    firstMove = random.randint(1,2)
    return "Player1 goes first" if firstMove == 1 else "Player2 goes first"
choose_first()
# Out:
# 'Player2 goes first'

# %% [markdown]
# **Step 6: Write a function that returns a boolean indicating whether a space on the board is freely available.**

# %%
def space_check(board, position):
    return True if board[position] != "X" and board[position] != "O" else False

# %% [markdown]
# **Step 7: Write a function that checks if the board is full and returns a boolean value. True if full, False otherwise.**

# %%
def full_board_check(board):
    for item in board:
        if item not in ["X", "O", "#"]:
            print(item)
            return False
    return True
test_board[8]=" "
display_board(test_board)
full_board_check(test_board)
# Out:
#  | |
# ------
#  | |
# ------
#  | |
# False

# %% [markdown]
# **Step 8: Write a function that asks for a player's next position (as a number 1-9) and then uses the function from step 6 to check if it's a free position. If it is, then return the position for later use.**

# %%
def player_choice(board):
    nextPosition = ''
    while nextPosition not in range(1,10):
        nextPosition = int(input("Please enter your next position (1-9): "))
    positionAvailability = space_check(board, nextPosition)
    return nextPosition if positionAvailability else False
player_choice(test_board)
# Out:
# Please enter your next position (1-9):  1
# 1

# %% [markdown]
# **Step 9: Write a function that asks the player if they want to play again and returns a boolean True if they do want to play again.**

# %%
def replay():
    playAgain = ''
    while playAgain not in ['y', 'n']:
        playAgain = input("Play again? y or n: ").lower()
    if playAgain == 'y':
        return True
    else:
        return False
replay()
# Out:
# Play again? y or n:  y
# True

# %% [markdown]
# **Step 10: Here comes the hard part! Use while loops and the functions you've made to run the game!**

# %%
print('Welcome to Tic Tac Toe!')
for index in range(1,10):
    test_board[index] = " "
test_board[1] = "X"
    
while True:
    # Set the game up here
    display_board(test_board)
    playerInput = player_input()
    game_on = full_board_check(test_board)
    #pass

    while not game_on:
        #Player 1 Turn
        print("Player1 Turn, marker {}".format(playerInput[0]))
        space = player_choice(test_board)
        
        while space == False:
            print("Position Occupied")
            print(spaceFree)
            spaceFree = player_choice(test_board)
            

        place_marker(test_board,playerInput[0],8,space)
        display_board(test_board)
        break
        
        # Player2's turn.
            
            #pass

    #if not replay():
        #break
    break
# Out:
# Welcome to Tic Tac Toe!
#  | |
# ------
#  | |
# ------
# X| |
# Player1, please choose your mark: X or O x
#
# Player1 Turn, marker X
# Please enter your next position (1-9):  1
# Position Occupied
# Please enter your next position (1-9):  2
# 2
# Position Occupied
# Please enter your next position (1-9):  3
# 3
# Position Occupied
# Please enter your next position (1-9):  x
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 20
#      18 while space==False:
#      19     print("Position Occupied")
# ---> 20     spaceFree = player_choice(test_board)
#      21     print(spaceFree)
#      23 place_marker(test_board,playerInput[0],8,space)
#
# Cell In[34], line 4, in player_choice(board)
#       2 nextPosition = ''
#       3 while nextPosition not in range(1,10):
# ----> 4     nextPosition = int(input("Please enter your next position (1-9): "))
#       5 positionAvailability = space_check(board, nextPosition)
#       6 return nextPosition if positionAvailability else False
#
# ValueError: invalid literal for int() with base 10: 'x'

# %% [markdown]
# ## Good Job!

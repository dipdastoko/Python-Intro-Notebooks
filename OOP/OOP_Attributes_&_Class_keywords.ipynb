# %%
class Dog():
    def __init__(self, breed,name,spot):
        self.breed = breed
        self.name = name
        self.spot = spot

# %%
my_dog = Dog('lab','Sammy',False)

# %%
my_dog.breed
my_dog.name
my_dog.spot
# Out:
# False

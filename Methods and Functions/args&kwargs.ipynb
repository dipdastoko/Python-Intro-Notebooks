# %%
def myfunc(a,b):
    return sum((a,b))*.05

# %%
myfunc(40,60)
# Out:
# 5.0

# %%
def myfunc(*args):
    print(args)

# %%
myfunc(2,3,4,5)
# Out:
# (2, 3, 4, 5)

# %%
def myfunc(**kwargs):
    if 'fruit' in kwargs:
        print('My fruit of choice is {}'.format(kwargs['fruit']))

# %%
myfunc(fruit='apple', veggie='cucumber')
# Out:
# My fruit of choice is apple

# %%
def myfunc(**kwargs):
    print(kwargs)

# %%
myfunc(fruit='apple', veggie='cucumber')
# Out:
# {'fruit': 'apple', 'veggie': 'cucumber'}

# %%
'lskjfd'[0].upper()
# Out:
# 'L'

# %%
outputStr=''
outputStr = outputStr+'hello'
outputStr
# Out:
# 'hello'

# %%
for letter in outputStr:
    print(letter)
# Out:
# h
# e
# l
# l
# o

# %%
'hello world'.split(" ")[0][0].upper()
# Out:
# 'H'

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more positional arguments, return the largest argument.

# %%
'hello'.capitalize(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 'hello'.capitalize(3)
#
# TypeError: str.capitalize() takes no arguments (1 given)

# %%
" ".join('a b c'.split(" ")[::-1])
# Out:
# 'c b a'

# %%
if 3 in [1,3,3]:
    print([1,3,3][2])
# Out:
# 3

# %%
'a'*3
# Out:
# 'aaa'

# %%
'aaa' in 'alskjaaalskdj'
# Out:
# True

# %%
'aaa' in 'klkfalfjdkalksfda'
# Out:
# False

# %%
"".join([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 "".join([1,2,3])
#
# TypeError: sequence item 0: expected str instance, int found

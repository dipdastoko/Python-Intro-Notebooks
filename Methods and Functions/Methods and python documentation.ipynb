# %%
mylist = [1,2,3,4]

# %%
mylist.append(5)

# %%
mylist.pop(4)
# Out:
# 5

# %%
mylist
# Out:
# [1, 2, 3, 4]

# %%
mylist
# Out:
# [1, 2, 3, 4]

# %%
from platform import python_version
print(python_version())
# Out:
# 3.13.5

# %%
def say_hello():
    print("hello")

# %%
say_hello()
# Out:
# hello

# %%
def say_hello(name):
    print(f'Hello {name}')

# %%
say_hello('Dip')
# Out:
# Hello Dip
